# %%
# !pip install pandas numpy opendatasets scikit-learn --quiet

# %%
import opendatasets as od
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib
import os

# %%
od.download('https://www.piworks.net/Upload/Document/Original/country_vaccination_stats.csv')
# Out:
# Using downloaded and verified file: ./country_vaccination_stats.csv

# %%
raw_df = pd.read_csv('country_vaccination_stats.csv')

# %%
raw_df
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
raw_df['daily_vaccinations'] = raw_df.groupby('country')['daily_vaccinations'].transform(lambda x:x.fillna(x.min()))

# %%
raw_df['daily_vaccinations'].fillna(0,inplace=True)

# %%
countryVaccMedian = raw_df.groupby('country')['daily_vaccinations'].median().sort_values(ascending=False).head(3)
countryVaccMedian
# Out:
# country
# United States    378253.0
# China            276786.0
# India            173922.0
# Name: daily_vaccinations, dtype: float64
